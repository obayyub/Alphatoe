# %%
from alphatoe import plot, game, interpretability
import torch
from torch import Tensor
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from importlib import reload
import tqdm
import pandas as pd

# %%
model = interpretability.load_model(
    "../scripts/models/prob all 8 layer control-20230718-185339"
)

# %%
games = pd.read_csv("../data/prob all 8 layer control-20230718-185339_stats.csv")
games.head()
# Out:
# /tmp/ipykernel_4489/629368561.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   games = pd.read_csv("../data/prob all 8 layer control-20230718-185339_stats.csv")
#       moves played  steps till end state winner  rotation 1  rotation 2
# 0  [0, 1, 3, 2, 6]                     5      X         399        1439  \
# 1  [0, 1, 3, 4, 6]                     5      X         396        1438
# 2  [0, 1, 3, 5, 6]                     5      X         398        1437
# 3  [0, 1, 3, 7, 6]                     5      X         395        1436
# 4  [0, 1, 3, 8, 6]                     5      X         397        1435
#
#    rotation 3  horizontal flip  vertical flip  training index train or test
# 0        1040             1114            325          241912          test  \
# 1        1043             1112            327          190522         train
# 2        1041             1113            326           90275         train
# 3        1044             1110            329           21994         train
# 4        1042             1111            328           48696         train
#
#   first win condition second win condition  end move loss
# 0         left column                  NaN       0.000005
# 1         left column                  NaN       0.000114
# 2         left column                  NaN       0.000007
# 3         left column                  NaN       0.000008
# 4         left column                  NaN       0.000013

# %% [markdown]
# ### Get games by win conditions

# %%
non_9_move_games = games[games["steps till end state"] != 9]
end_game_types = list(games["first win condition"].unique())

game_kinds = [
    [
        [10] + eval(move)
        for move in non_9_move_games[
            (non_9_move_games["first win condition"] == game_type)
            | (non_9_move_games["second win condition"] == game_type)
        ]["moves played"]
    ]
    for game_type in end_game_types[:-1]
]

# %%
for games in game_kinds:
    print(len(games))
# Out:
# 14436
# 20340
# 14436
# 14436
# 20340
# 14436
# 14436
# 14436

# %% [markdown]
# ### Get pre-mlp residual stream contents

# %%
def pre_mlp_residual(seq):
    def hook(module, input, output):
        result = output.clone()
        module.captured = result

    try:
        handle = model.blocks[0].hook_resid_mid.register_forward_hook(hook)
        with torch.no_grad():
            model(seq)
        activations = model.blocks[0].hook_resid_mid.captured
        handle.remove()
    except Exception as e:
        handle.remove()
        raise e

    return activations

# %%
residual_stream = pre_mlp_residual(torch.tensor([10, 1, 2, 3]))

# %%
residual_stream.shape
# Out:
# torch.Size([1, 4, 128])

# %% [markdown]
# ### Get residual stream across 1000 games of a type

# %%
games = game_kinds[0][:1000]

# %%
len(games)
# Out:
# 1000

# %%
# left column
games[0]
# Out:
# [10, 0, 1, 3, 2, 6]

# %%
# TODO: games are different sizes, batching requires some work, who cares for now
resid_vectors = []
for game in games:
    resid_vectors.append(
        interpretability.capture_forward_pass(
            model, model.blocks[0].hook_resid_mid, torch.tensor(game)
        )[0, -1]
    )
resid_tensor = torch.stack(resid_vectors).detach().cpu()

# %%
resid_tensor.shape
# Out:
# torch.Size([1000, 128])

# %% [markdown]
# ### Taking the PCA of the residual stream across games

# %%
mean_centered = resid_tensor - resid_tensor.mean(dim=0)

# %%
resid_tensor
# Out:
# tensor([[ 0.0431,  0.5041, -0.3265,  ..., -0.6198, -0.3301, -0.5209],
#         [-0.0807,  0.5625, -0.3957,  ..., -0.4737, -0.2211, -0.6115],
#         [-0.0240,  0.5285, -0.2413,  ..., -0.5456, -0.3942, -0.6143],
#         ...,
#         [-0.3022,  0.0194,  0.1407,  ..., -0.1070, -0.3671, -0.2893],
#         [-0.4039,  0.0594,  0.0815,  ...,  0.0336, -0.2753, -0.3656],
#         [-0.3621,  0.0250,  0.2009,  ..., -0.0330, -0.4281, -0.3731]])

# %%
PCA_info = interpretability.pca(resid_tensor)
# Out:
# /home/thetis/Code/Tic-Tac-Transformer/alphatoe/interpretability.py:215: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at ../aten/src/ATen/native/Copy.cpp:250.)
#   real_eigenvalues: Tensor = eigenvalues.float()

# %%
R2 = PCA_info["R2"]
variances = PCA_info["variances"]
principal_components = PCA_info["principal components"]
projected_data = PCA_info["projected data"]

# %%
print(R2)
print(variances)
print(principal_components)
print(projected_data)
# Out:
# tensor([0.2270, 0.1849, 0.1348, 0.1120, 0.0887, 0.0730, 0.0708, 0.0604])
# tensor([0.6929, 0.5643, 0.4114, 0.3417, 0.2709, 0.2228, 0.2162, 0.1842])
# tensor([[ 0.0262, -0.0082, -0.1195,  ...,  0.0749,  0.0488, -0.0993],
#         [-0.0438,  0.0193, -0.0306,  ..., -0.0423,  0.0093, -0.1454],
#         [-0.0173, -0.0830,  0.0602,  ...,  0.0776, -0.2071,  0.0710],
#         ...,
#         [ 0.0472, -0.2161, -0.0483,  ..., -0.0894, -0.0569,  0.0392],
#         [-0.0538,  0.0824,  0.0281,  ..., -0.1813,  0.1037,  0.0822],
#         [-0.0968, -0.0381,  0.0638,  ...,  0.0479,  0.0616, -0.0289]])
# tensor([[-0.5320,  1.0366, -0.1912,  ..., -0.5966,  0.2388, -0.4008],
#         [-0.5350,  0.9054, -0.2894,  ..., -0.5321,  0.2063, -0.3617],
#         [-0.5000,  1.0873, -0.2263,  ..., -0.3949, -0.5261, -0.5436],
#         ...,
#         [-1.4458, -0.7565,  0.1498,  ...,  0.0038, -0.2217,  1.7975],
#         [-1.4579, -0.8730,  0.0678,  ...,  0.0669, -0.2429,  1.8418],
#         [-1.4305, -0.7070,  0.1236,  ...,  0.1837, -0.9205,  1.6695]])

# %% [markdown]
# ### This isn't enough, we need a way to associate each game with it's residual stream projected onto each principal component

# %%
# If we sort and take the indices across the 1000 dimension, that'll tell us what games occured in which placement of the variance
projected_data.shape
# Out:
# torch.Size([1000, 8])

# %%
# We can "recover" our data by doing projected_data @ principal_components.T
principal_components.shape
# Out:
# torch.Size([128, 8])

# %%
def sort_PCA_projections(projected_data, index):
    data_vec = projected_data[:, index]
    # principal_component = principal_components[:, index]
    game_indices = torch.argsort(data_vec)
    return game_indices

# %%
first_component_games = [
    game_kinds[0][i] for i in sort_PCA_projections(resid_tensor, 0)
]
for moves in first_component_games:
    print(moves)
    print("-------------------")
# Out:
# [10, 0, 1, 4, 5, 3, 7, 6]
# -------------------
# [10, 0, 1, 4, 7, 3, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 4, 7, 6]
# -------------------
# [10, 0, 1, 3, 7, 4, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 7, 4, 6]
# -------------------
# [10, 0, 1, 3, 4, 7, 5, 6]
# -------------------
# [10, 0, 1, 4, 5, 6, 7, 3]
# -------------------
# [10, 0, 1, 4, 7, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 5, 4, 7, 3]
# -------------------
# [10, 0, 1, 6, 7, 4, 5, 3]
# -------------------
# [10, 0, 1, 4, 2, 3, 7, 6]
# -------------------
# [10, 0, 1, 6, 5, 7, 4, 3]
# -------------------
# [10, 0, 1, 6, 4, 7, 5, 3]
# -------------------
# [10, 0, 1, 4, 7, 3, 2, 6]
# -------------------
# [10, 0, 1, 3, 2, 4, 7, 6]
# -------------------
# [10, 0, 1, 3, 7, 4, 2, 6]
# -------------------
# [10, 0, 1, 3, 2, 7, 4, 6]
# -------------------
# [10, 0, 1, 3, 4, 7, 2, 6]
# -------------------
# [10, 0, 1, 4, 2, 6, 7, 3]
# -------------------
# [10, 0, 1, 4, 7, 6, 2, 3]
# -------------------
# [10, 0, 1, 4, 8, 3, 7, 6]
# -------------------
# [10, 0, 1, 6, 2, 4, 7, 3]
# -------------------
# [10, 0, 1, 6, 7, 4, 2, 3]
# -------------------
# [10, 0, 1, 4, 7, 3, 8, 6]
# -------------------
# [10, 0, 1, 4, 2, 3, 5, 6]
# -------------------
# [10, 0, 1, 4, 5, 3, 2, 6]
# -------------------
# [10, 0, 1, 3, 8, 4, 7, 6]
# -------------------
# [10, 0, 1, 6, 2, 7, 4, 3]
# -------------------
# [10, 0, 1, 3, 7, 4, 8, 6]
# -------------------
# [10, 0, 1, 6, 4, 7, 2, 3]
# -------------------
# [10, 0, 1, 3, 8, 7, 4, 6]
# -------------------
# [10, 0, 1, 3, 2, 4, 5, 6]
# -------------------
# [10, 0, 1, 3, 2, 7, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 4, 2, 6]
# -------------------
# [10, 0, 1, 3, 5, 7, 2, 6]
# -------------------
# [10, 0, 1, 3, 4, 7, 8, 6]
# -------------------
# [10, 7, 0, 5, 3, 4, 6]
# -------------------
# [10, 5, 0, 7, 3, 4, 6]
# -------------------
# [10, 5, 0, 4, 3, 7, 6]
# -------------------
# [10, 4, 0, 5, 3, 7, 6]
# -------------------
# [10, 7, 0, 4, 3, 5, 6]
# -------------------
# [10, 0, 1, 4, 7, 6, 8, 3]
# -------------------
# [10, 4, 0, 7, 3, 5, 6]
# -------------------
# [10, 0, 1, 4, 8, 6, 7, 3]
# -------------------
# [10, 7, 3, 5, 0, 4, 6]
# -------------------
# [10, 5, 3, 7, 0, 4, 6]
# -------------------
# [10, 5, 3, 4, 0, 7, 6]
# -------------------
# [10, 4, 3, 5, 0, 7, 6]
# -------------------
# [10, 7, 3, 4, 0, 5, 6]
# -------------------
# [10, 4, 3, 7, 0, 5, 6]
# -------------------
# [10, 0, 1, 4, 5, 6, 2, 3]
# -------------------
# [10, 0, 1, 4, 2, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 7, 4, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 4, 7, 3]
# -------------------
# [10, 0, 1, 6, 5, 4, 2, 3]
# -------------------
# [10, 0, 1, 6, 2, 4, 5, 3]
# -------------------
# [10, 0, 1, 4, 8, 3, 5, 6]
# -------------------
# [10, 0, 1, 4, 5, 3, 8, 6]
# -------------------
# [10, 0, 1, 6, 5, 7, 2, 3]
# -------------------
# [10, 0, 1, 6, 2, 7, 5, 3]
# -------------------
# [10, 0, 1, 6, 4, 7, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 7, 4, 3]
# -------------------
# [10, 4, 6, 5, 0, 7, 3]
# -------------------
# [10, 5, 6, 4, 0, 7, 3]
# -------------------
# [10, 7, 6, 5, 0, 4, 3]
# -------------------
# [10, 4, 0, 5, 6, 7, 3]
# -------------------
# [10, 5, 0, 4, 6, 7, 3]
# -------------------
# [10, 5, 6, 7, 0, 4, 3]
# -------------------
# [10, 7, 0, 5, 6, 4, 3]
# -------------------
# [10, 5, 0, 7, 6, 4, 3]
# -------------------
# [10, 7, 6, 4, 0, 5, 3]
# -------------------
# [10, 4, 6, 7, 0, 5, 3]
# -------------------
# [10, 7, 0, 4, 6, 5, 3]
# -------------------
# [10, 4, 0, 7, 6, 5, 3]
# -------------------
# [10, 0, 1, 3, 8, 7, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 7, 8, 6]
# -------------------
# [10, 0, 1, 3, 8, 4, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 4, 8, 6]
# -------------------
# [10, 0, 1, 4, 5, 6, 8, 3]
# -------------------
# [10, 0, 1, 4, 8, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 5, 4, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 4, 5, 3]
# -------------------
# [10, 0, 1, 6, 5, 7, 8, 3]
# -------------------
# [10, 2, 0, 7, 3, 4, 6]
# -------------------
# [10, 2, 0, 4, 3, 7, 6]
# -------------------
# [10, 7, 0, 2, 3, 4, 6]
# -------------------
# [10, 7, 0, 4, 3, 2, 6]
# -------------------
# [10, 4, 0, 2, 3, 7, 6]
# -------------------
# [10, 4, 0, 7, 3, 2, 6]
# -------------------
# [10, 0, 1, 6, 8, 7, 5, 3]
# -------------------
# [10, 2, 3, 7, 0, 4, 6]
# -------------------
# [10, 2, 3, 4, 0, 7, 6]
# -------------------
# [10, 7, 3, 2, 0, 4, 6]
# -------------------
# [10, 7, 3, 4, 0, 2, 6]
# -------------------
# [10, 4, 3, 2, 0, 7, 6]
# -------------------
# [10, 4, 3, 7, 0, 2, 6]
# -------------------
# [10, 0, 1, 4, 2, 3, 8, 6]
# -------------------
# [10, 0, 1, 4, 8, 3, 2, 6]
# -------------------
# [10, 0, 1, 3, 2, 4, 8, 6]
# -------------------
# [10, 4, 6, 2, 0, 7, 3]
# -------------------
# [10, 0, 1, 3, 8, 4, 2, 6]
# -------------------
# [10, 7, 6, 2, 0, 4, 3]
# -------------------
# [10, 4, 0, 2, 6, 7, 3]
# -------------------
# [10, 2, 6, 4, 0, 7, 3]
# -------------------
# [10, 7, 6, 4, 0, 2, 3]
# -------------------
# [10, 7, 0, 2, 6, 4, 3]
# -------------------
# [10, 4, 6, 7, 0, 2, 3]
# -------------------
# [10, 2, 0, 4, 6, 7, 3]
# -------------------
# [10, 7, 0, 4, 6, 2, 3]
# -------------------
# [10, 2, 6, 7, 0, 4, 3]
# -------------------
# [10, 4, 0, 7, 6, 2, 3]
# -------------------
# [10, 2, 0, 7, 6, 4, 3]
# -------------------
# [10, 0, 1, 3, 2, 7, 8, 6]
# -------------------
# [10, 0, 1, 3, 8, 7, 2, 6]
# -------------------
# [10, 0, 1, 5, 2, 3, 7, 6]
# -------------------
# [10, 0, 1, 5, 7, 3, 2, 6]
# -------------------
# [10, 7, 0, 8, 3, 4, 6]
# -------------------
# [10, 4, 0, 8, 3, 7, 6]
# -------------------
# [10, 7, 0, 4, 3, 8, 6]
# -------------------
# [10, 8, 0, 7, 3, 4, 6]
# -------------------
# [10, 8, 0, 4, 3, 7, 6]
# -------------------
# [10, 4, 0, 7, 3, 8, 6]
# -------------------
# [10, 7, 3, 8, 0, 4, 6]
# -------------------
# [10, 4, 3, 8, 0, 7, 6]
# -------------------
# [10, 7, 3, 4, 0, 8, 6]
# -------------------
# [10, 8, 3, 7, 0, 4, 6]
# -------------------
# [10, 8, 3, 4, 0, 7, 6]
# -------------------
# [10, 4, 3, 7, 0, 8, 6]
# -------------------
# [10, 0, 1, 3, 2, 5, 7, 6]
# -------------------
# [10, 0, 1, 5, 2, 3, 4, 6]
# -------------------
# [10, 0, 1, 4, 2, 6, 8, 3]
# -------------------
# [10, 0, 1, 4, 8, 6, 2, 3]
# -------------------
# [10, 0, 1, 3, 7, 5, 2, 6]
# -------------------
# [10, 0, 1, 5, 4, 3, 2, 6]
# -------------------
# [10, 0, 1, 6, 2, 4, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 4, 2, 3]
# -------------------
# [10, 0, 1, 3, 2, 5, 4, 6]
# -------------------
# [10, 2, 0, 5, 3, 7, 6]
# -------------------
# [10, 7, 0, 5, 3, 2, 6]
# -------------------
# [10, 2, 0, 7, 3, 5, 6]
# -------------------
# [10, 5, 0, 2, 3, 7, 6]
# -------------------
# [10, 5, 0, 7, 3, 2, 6]
# -------------------
# [10, 7, 0, 2, 3, 5, 6]
# -------------------
# [10, 0, 1, 3, 4, 5, 2, 6]
# -------------------
# [10, 5, 0, 1, 3, 7, 6]
# -------------------
# [10, 7, 0, 1, 3, 5, 6]
# -------------------
# [10, 1, 0, 5, 3, 7, 6]
# -------------------
# [10, 1, 0, 7, 3, 5, 6]
# -------------------
# [10, 2, 0, 5, 3, 4, 6]
# -------------------
# [10, 2, 0, 4, 3, 5, 6]
# -------------------
# [10, 5, 0, 2, 3, 4, 6]
# -------------------
# [10, 7, 0, 5, 3, 1, 6]
# -------------------
# [10, 5, 0, 4, 3, 2, 6]
# -------------------
# [10, 5, 0, 7, 3, 1, 6]
# -------------------
# [10, 4, 0, 5, 3, 2, 6]
# -------------------
# [10, 4, 0, 2, 3, 5, 6]
# -------------------
# [10, 0, 1, 6, 2, 7, 8, 3]
# -------------------
# [10, 5, 0, 1, 3, 4, 6]
# -------------------
# [10, 1, 0, 5, 3, 4, 6]
# -------------------
# [10, 2, 3, 5, 0, 7, 6]
# -------------------
# [10, 4, 6, 8, 0, 7, 3]
# -------------------
# [10, 4, 0, 1, 3, 5, 6]
# -------------------
# [10, 7, 6, 8, 0, 4, 3]
# -------------------
# [10, 4, 0, 8, 6, 7, 3]
# -------------------
# [10, 1, 0, 4, 3, 5, 6]
# -------------------
# [10, 7, 0, 8, 6, 4, 3]
# -------------------
# [10, 7, 3, 5, 0, 2, 6]
# -------------------
# [10, 2, 3, 7, 0, 5, 6]
# -------------------
# [10, 5, 3, 2, 0, 7, 6]
# -------------------
# [10, 5, 3, 7, 0, 2, 6]
# -------------------
# [10, 0, 1, 6, 8, 7, 2, 3]
# -------------------
# [10, 7, 3, 2, 0, 5, 6]
# -------------------
# [10, 7, 6, 4, 0, 8, 3]
# -------------------
# [10, 4, 6, 7, 0, 8, 3]
# -------------------
# [10, 5, 0, 4, 3, 1, 6]
# -------------------
# [10, 7, 0, 4, 6, 8, 3]
# -------------------
# [10, 4, 0, 7, 6, 8, 3]
# -------------------
# [10, 4, 0, 5, 3, 1, 6]
# -------------------
# [10, 8, 6, 4, 0, 7, 3]
# -------------------
# [10, 8, 0, 4, 6, 7, 3]
# -------------------
# [10, 8, 6, 7, 0, 4, 3]
# -------------------
# [10, 5, 3, 1, 0, 7, 6]
# -------------------
# [10, 8, 0, 7, 6, 4, 3]
# -------------------
# [10, 7, 3, 1, 0, 5, 6]
# -------------------
# [10, 1, 3, 5, 0, 7, 6]
# -------------------
# [10, 1, 3, 7, 0, 5, 6]
# -------------------
# [10, 2, 3, 5, 0, 4, 6]
# -------------------
# [10, 2, 3, 4, 0, 5, 6]
# -------------------
# [10, 5, 3, 2, 0, 4, 6]
# -------------------
# [10, 7, 3, 5, 0, 1, 6]
# -------------------
# [10, 5, 3, 4, 0, 2, 6]
# -------------------
# [10, 5, 3, 7, 0, 1, 6]
# -------------------
# [10, 4, 3, 5, 0, 2, 6]
# -------------------
# [10, 4, 3, 2, 0, 5, 6]
# -------------------
# [10, 5, 3, 1, 0, 4, 6]
# -------------------
# [10, 1, 3, 5, 0, 4, 6]
# -------------------
# [10, 4, 3, 1, 0, 5, 6]
# -------------------
# [10, 1, 3, 4, 0, 5, 6]
# -------------------
# [10, 5, 3, 4, 0, 1, 6]
# -------------------
# [10, 4, 3, 5, 0, 1, 6]
# -------------------
# [10, 0, 1, 5, 2, 6, 7, 3]
# -------------------
# [10, 0, 1, 5, 7, 6, 2, 3]
# -------------------
# [10, 0, 1, 6, 2, 5, 7, 3]
# -------------------
# [10, 0, 1, 5, 8, 3, 7, 6]
# -------------------
# [10, 0, 1, 6, 7, 5, 2, 3]
# -------------------
# [10, 0, 1, 5, 7, 3, 8, 6]
# -------------------
# [10, 0, 1, 5, 2, 6, 4, 3]
# -------------------
# [10, 0, 1, 5, 4, 6, 2, 3]
# -------------------
# [10, 5, 6, 2, 0, 7, 3]
# -------------------
# [10, 5, 0, 2, 6, 7, 3]
# -------------------
# [10, 2, 6, 5, 0, 7, 3]
# -------------------
# [10, 7, 6, 5, 0, 2, 3]
# -------------------
# [10, 2, 0, 5, 6, 7, 3]
# -------------------
# [10, 5, 6, 7, 0, 2, 3]
# -------------------
# [10, 7, 0, 5, 6, 2, 3]
# -------------------
# [10, 5, 0, 7, 6, 2, 3]
# -------------------
# [10, 7, 6, 2, 0, 5, 3]
# -------------------
# [10, 7, 0, 2, 6, 5, 3]
# -------------------
# [10, 2, 6, 7, 0, 5, 3]
# -------------------
# [10, 5, 6, 1, 0, 7, 3]
# -------------------
# [10, 2, 0, 7, 6, 5, 3]
# -------------------
# [10, 5, 0, 1, 6, 7, 3]
# -------------------
# [10, 5, 6, 2, 0, 4, 3]
# -------------------
# [10, 4, 6, 5, 0, 2, 3]
# -------------------
# [10, 5, 6, 4, 0, 2, 3]
# -------------------
# [10, 7, 6, 1, 0, 5, 3]
# -------------------
# [10, 5, 0, 2, 6, 4, 3]
# -------------------
# [10, 2, 6, 5, 0, 4, 3]
# -------------------
# [10, 4, 0, 5, 6, 2, 3]
# -------------------
# [10, 5, 0, 4, 6, 2, 3]
# -------------------
# [10, 1, 6, 5, 0, 7, 3]
# -------------------
# [10, 2, 0, 5, 6, 4, 3]
# -------------------
# [10, 7, 0, 1, 6, 5, 3]
# -------------------
# [10, 1, 0, 5, 6, 7, 3]
# -------------------
# [10, 4, 6, 2, 0, 5, 3]
# -------------------
# [10, 7, 6, 5, 0, 1, 3]
# -------------------
# [10, 4, 0, 2, 6, 5, 3]
# -------------------
# [10, 2, 6, 4, 0, 5, 3]
# -------------------
# [10, 5, 6, 7, 0, 1, 3]
# -------------------
# [10, 7, 0, 5, 6, 1, 3]
# -------------------
# [10, 2, 0, 4, 6, 5, 3]
# -------------------
# [10, 5, 0, 7, 6, 1, 3]
# -------------------
# [10, 1, 6, 7, 0, 5, 3]
# -------------------
# [10, 1, 0, 7, 6, 5, 3]
# -------------------
# [10, 5, 6, 1, 0, 4, 3]
# -------------------
# [10, 5, 0, 1, 6, 4, 3]
# -------------------
# [10, 4, 6, 1, 0, 5, 3]
# -------------------
# [10, 0, 1, 6, 2, 5, 4, 3]
# -------------------
# [10, 4, 0, 1, 6, 5, 3]
# -------------------
# [10, 1, 6, 5, 0, 4, 3]
# -------------------
# [10, 1, 0, 5, 6, 4, 3]
# -------------------
# [10, 4, 6, 5, 0, 1, 3]
# -------------------
# [10, 5, 6, 4, 0, 1, 3]
# -------------------
# [10, 4, 0, 5, 6, 1, 3]
# -------------------
# [10, 5, 0, 4, 6, 1, 3]
# -------------------
# [10, 1, 6, 4, 0, 5, 3]
# -------------------
# [10, 1, 0, 4, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 4, 5, 2, 3]
# -------------------
# [10, 0, 1, 3, 8, 5, 7, 6]
# -------------------
# [10, 0, 1, 5, 8, 3, 4, 6]
# -------------------
# [10, 0, 1, 3, 7, 5, 8, 6]
# -------------------
# [10, 0, 1, 5, 4, 3, 8, 6]
# -------------------
# [10, 5, 0, 8, 3, 7, 6]
# -------------------
# [10, 7, 0, 8, 3, 5, 6]
# -------------------
# [10, 7, 0, 5, 3, 8, 6]
# -------------------
# [10, 8, 0, 5, 3, 7, 6]
# -------------------
# [10, 5, 0, 7, 3, 8, 6]
# -------------------
# [10, 8, 0, 7, 3, 5, 6]
# -------------------
# [10, 5, 0, 8, 3, 4, 6]
# -------------------
# [10, 4, 0, 8, 3, 5, 6]
# -------------------
# [10, 8, 0, 5, 3, 4, 6]
# -------------------
# [10, 5, 0, 4, 3, 8, 6]
# -------------------
# [10, 4, 0, 5, 3, 8, 6]
# -------------------
# [10, 8, 0, 4, 3, 5, 6]
# -------------------
# [10, 5, 3, 8, 0, 7, 6]
# -------------------
# [10, 7, 3, 8, 0, 5, 6]
# -------------------
# [10, 7, 3, 5, 0, 8, 6]
# -------------------
# [10, 8, 3, 5, 0, 7, 6]
# -------------------
# [10, 5, 3, 7, 0, 8, 6]
# -------------------
# [10, 8, 3, 7, 0, 5, 6]
# -------------------
# [10, 0, 1, 3, 8, 5, 4, 6]
# -------------------
# [10, 5, 3, 8, 0, 4, 6]
# -------------------
# [10, 4, 3, 8, 0, 5, 6]
# -------------------
# [10, 8, 3, 5, 0, 4, 6]
# -------------------
# [10, 5, 3, 4, 0, 8, 6]
# -------------------
# [10, 4, 3, 5, 0, 8, 6]
# -------------------
# [10, 8, 3, 4, 0, 5, 6]
# -------------------
# [10, 7, 6, 5, 3, 4, 0]
# -------------------
# [10, 5, 6, 7, 3, 4, 0]
# -------------------
# [10, 5, 6, 4, 3, 7, 0]
# -------------------
# [10, 4, 6, 5, 3, 7, 0]
# -------------------
# [10, 7, 6, 4, 3, 5, 0]
# -------------------
# [10, 0, 1, 3, 4, 5, 8, 6]
# -------------------
# [10, 4, 6, 7, 3, 5, 0]
# -------------------
# [10, 7, 3, 5, 6, 4, 0]
# -------------------
# [10, 5, 3, 7, 6, 4, 0]
# -------------------
# [10, 5, 3, 4, 6, 7, 0]
# -------------------
# [10, 4, 3, 5, 6, 7, 0]
# -------------------
# [10, 7, 3, 4, 6, 5, 0]
# -------------------
# [10, 4, 3, 7, 6, 5, 0]
# -------------------
# [10, 0, 1, 5, 7, 6, 8, 3]
# -------------------
# [10, 0, 1, 5, 8, 6, 7, 3]
# -------------------
# [10, 5, 6, 8, 0, 7, 3]
# -------------------
# [10, 5, 0, 8, 6, 7, 3]
# -------------------
# [10, 7, 6, 8, 0, 5, 3]
# -------------------
# [10, 7, 0, 8, 6, 5, 3]
# -------------------
# [10, 7, 6, 5, 0, 8, 3]
# -------------------
# [10, 5, 6, 7, 0, 8, 3]
# -------------------
# [10, 7, 0, 5, 6, 8, 3]
# -------------------
# [10, 5, 0, 7, 6, 8, 3]
# -------------------
# [10, 8, 6, 5, 0, 7, 3]
# -------------------
# [10, 8, 0, 5, 6, 7, 3]
# -------------------
# [10, 5, 6, 8, 0, 4, 3]
# -------------------
# [10, 8, 6, 7, 0, 5, 3]
# -------------------
# [10, 5, 0, 8, 6, 4, 3]
# -------------------
# [10, 8, 0, 7, 6, 5, 3]
# -------------------
# [10, 4, 6, 8, 0, 5, 3]
# -------------------
# [10, 4, 0, 8, 6, 5, 3]
# -------------------
# [10, 4, 6, 5, 0, 8, 3]
# -------------------
# [10, 5, 6, 4, 0, 8, 3]
# -------------------
# [10, 4, 0, 5, 6, 8, 3]
# -------------------
# [10, 5, 0, 4, 6, 8, 3]
# -------------------
# [10, 0, 1, 6, 7, 5, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 5, 7, 3]
# -------------------
# [10, 8, 6, 5, 0, 4, 3]
# -------------------
# [10, 8, 0, 5, 6, 4, 3]
# -------------------
# [10, 8, 6, 4, 0, 5, 3]
# -------------------
# [10, 8, 0, 4, 6, 5, 3]
# -------------------
# [10, 2, 0, 1, 3, 7, 6]
# -------------------
# [10, 7, 0, 1, 3, 2, 6]
# -------------------
# [10, 1, 0, 2, 3, 7, 6]
# -------------------
# [10, 1, 0, 7, 3, 2, 6]
# -------------------
# [10, 2, 0, 1, 3, 4, 6]
# -------------------
# [10, 2, 0, 7, 3, 1, 6]
# -------------------
# [10, 7, 0, 2, 3, 1, 6]
# -------------------
# [10, 4, 0, 1, 3, 2, 6]
# -------------------
# [10, 1, 0, 2, 3, 4, 6]
# -------------------
# [10, 1, 0, 4, 3, 2, 6]
# -------------------
# [10, 0, 1, 5, 4, 6, 8, 3]
# -------------------
# [10, 2, 0, 4, 3, 1, 6]
# -------------------
# [10, 0, 1, 5, 8, 6, 4, 3]
# -------------------
# [10, 4, 0, 2, 3, 1, 6]
# -------------------
# [10, 2, 3, 1, 0, 7, 6]
# -------------------
# [10, 7, 3, 1, 0, 2, 6]
# -------------------
# [10, 1, 3, 2, 0, 7, 6]
# -------------------
# [10, 1, 3, 7, 0, 2, 6]
# -------------------
# [10, 2, 3, 1, 0, 4, 6]
# -------------------
# [10, 2, 3, 7, 0, 1, 6]
# -------------------
# [10, 7, 3, 2, 0, 1, 6]
# -------------------
# [10, 4, 3, 1, 0, 2, 6]
# -------------------
# [10, 1, 3, 2, 0, 4, 6]
# -------------------
# [10, 1, 3, 4, 0, 2, 6]
# -------------------
# [10, 2, 3, 4, 0, 1, 6]
# -------------------
# [10, 0, 1, 6, 4, 5, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 5, 4, 3]
# -------------------
# [10, 4, 3, 2, 0, 1, 6]
# -------------------
# [10, 2, 6, 1, 0, 7, 3]
# -------------------
# [10, 7, 6, 1, 0, 2, 3]
# -------------------
# [10, 2, 0, 1, 6, 7, 3]
# -------------------
# [10, 7, 0, 1, 6, 2, 3]
# -------------------
# [10, 4, 6, 1, 0, 2, 3]
# -------------------
# [10, 2, 6, 1, 0, 4, 3]
# -------------------
# [10, 1, 6, 2, 0, 7, 3]
# -------------------
# [10, 4, 0, 1, 6, 2, 3]
# -------------------
# [10, 2, 0, 1, 6, 4, 3]
# -------------------
# [10, 1, 0, 2, 6, 7, 3]
# -------------------
# [10, 1, 6, 7, 0, 2, 3]
# -------------------
# [10, 7, 6, 2, 0, 1, 3]
# -------------------
# [10, 1, 0, 7, 6, 2, 3]
# -------------------
# [10, 7, 0, 2, 6, 1, 3]
# -------------------
# [10, 1, 6, 2, 0, 4, 3]
# -------------------
# [10, 2, 6, 7, 0, 1, 3]
# -------------------
# [10, 1, 6, 4, 0, 2, 3]
# -------------------
# [10, 1, 0, 2, 6, 4, 3]
# -------------------
# [10, 2, 0, 7, 6, 1, 3]
# -------------------
# [10, 1, 0, 4, 6, 2, 3]
# -------------------
# [10, 4, 6, 2, 0, 1, 3]
# -------------------
# [10, 4, 0, 2, 6, 1, 3]
# -------------------
# [10, 2, 6, 4, 0, 1, 3]
# -------------------
# [10, 2, 0, 4, 6, 1, 3]
# -------------------
# [10, 3, 4, 0, 7, 6]
# -------------------
# [10, 3, 7, 0, 4, 6]
# -------------------
# [10, 0, 4, 3, 7, 6]
# -------------------
# [10, 0, 7, 3, 4, 6]
# -------------------
# [10, 2, 0, 8, 3, 7, 6]
# -------------------
# [10, 7, 0, 8, 3, 2, 6]
# -------------------
# [10, 2, 0, 7, 3, 8, 6]
# -------------------
# [10, 7, 0, 2, 3, 8, 6]
# -------------------
# [10, 8, 0, 2, 3, 7, 6]
# -------------------
# [10, 8, 0, 7, 3, 2, 6]
# -------------------
# [10, 2, 0, 8, 3, 4, 6]
# -------------------
# [10, 1, 0, 8, 3, 7, 6]
# -------------------
# [10, 4, 0, 8, 3, 2, 6]
# -------------------
# [10, 2, 0, 4, 3, 8, 6]
# -------------------
# [10, 7, 0, 1, 3, 8, 6]
# -------------------
# [10, 8, 0, 1, 3, 7, 6]
# -------------------
# [10, 1, 0, 7, 3, 8, 6]
# -------------------
# [10, 8, 0, 2, 3, 4, 6]
# -------------------
# [10, 8, 0, 4, 3, 2, 6]
# -------------------
# [10, 4, 0, 2, 3, 8, 6]
# -------------------
# [10, 7, 0, 8, 3, 1, 6]
# -------------------
# [10, 8, 0, 7, 3, 1, 6]
# -------------------
# [10, 1, 0, 8, 3, 4, 6]
# -------------------
# [10, 8, 0, 1, 3, 4, 6]
# -------------------
# [10, 4, 0, 1, 3, 8, 6]
# -------------------
# [10, 1, 0, 4, 3, 8, 6]
# -------------------
# [10, 2, 3, 8, 0, 7, 6]
# -------------------
# [10, 7, 3, 8, 0, 2, 6]
# -------------------
# [10, 4, 0, 8, 3, 1, 6]
# -------------------
# [10, 2, 3, 7, 0, 8, 6]
# -------------------
# [10, 8, 0, 4, 3, 1, 6]
# -------------------
# [10, 7, 3, 2, 0, 8, 6]
# -------------------
# [10, 8, 3, 2, 0, 7, 6]
# -------------------
# [10, 8, 3, 7, 0, 2, 6]
# -------------------
# [10, 2, 3, 8, 0, 4, 6]
# -------------------
# [10, 1, 3, 8, 0, 7, 6]
# -------------------
# [10, 4, 3, 8, 0, 2, 6]
# -------------------
# [10, 2, 3, 4, 0, 8, 6]
# -------------------
# [10, 7, 3, 1, 0, 8, 6]
# -------------------
# [10, 8, 3, 1, 0, 7, 6]
# -------------------
# [10, 8, 3, 2, 0, 4, 6]
# -------------------
# [10, 1, 3, 7, 0, 8, 6]
# -------------------
# [10, 8, 3, 4, 0, 2, 6]
# -------------------
# [10, 4, 3, 2, 0, 8, 6]
# -------------------
# [10, 7, 3, 8, 0, 1, 6]
# -------------------
# [10, 8, 3, 7, 0, 1, 6]
# -------------------
# [10, 1, 3, 8, 0, 4, 6]
# -------------------
# [10, 8, 3, 1, 0, 4, 6]
# -------------------
# [10, 4, 3, 1, 0, 8, 6]
# -------------------
# [10, 0, 4, 6, 7, 3]
# -------------------
# [10, 1, 3, 4, 0, 8, 6]
# -------------------
# [10, 0, 7, 6, 4, 3]
# -------------------
# [10, 4, 3, 8, 0, 1, 6]
# -------------------
# [10, 7, 6, 2, 3, 4, 0]
# -------------------
# [10, 2, 6, 7, 3, 4, 0]
# -------------------
# [10, 2, 6, 4, 3, 7, 0]
# -------------------
# [10, 8, 3, 4, 0, 1, 6]
# -------------------
# [10, 4, 6, 2, 3, 7, 0]
# -------------------
# [10, 7, 6, 4, 3, 2, 0]
# -------------------
# [10, 4, 6, 7, 3, 2, 0]
# -------------------
# [10, 7, 3, 2, 6, 4, 0]
# -------------------
# [10, 2, 3, 7, 6, 4, 0]
# -------------------
# [10, 2, 3, 4, 6, 7, 0]
# -------------------
# [10, 4, 3, 2, 6, 7, 0]
# -------------------
# [10, 7, 3, 4, 6, 2, 0]
# -------------------
# [10, 4, 3, 7, 6, 2, 0]
# -------------------
# [10, 6, 4, 0, 7, 3]
# -------------------
# [10, 6, 7, 0, 4, 3]
# -------------------
# [10, 2, 6, 8, 0, 7, 3]
# -------------------
# [10, 7, 6, 8, 0, 2, 3]
# -------------------
# [10, 2, 0, 8, 6, 7, 3]
# -------------------
# [10, 7, 0, 8, 6, 2, 3]
# -------------------
# [10, 2, 0, 1, 3, 5, 6]
# -------------------
# [10, 5, 0, 1, 3, 2, 6]
# -------------------
# [10, 4, 6, 8, 0, 2, 3]
# -------------------
# [10, 2, 6, 8, 0, 4, 3]
# -------------------
# [10, 7, 6, 2, 0, 8, 3]
# -------------------
# [10, 4, 0, 8, 6, 2, 3]
# -------------------
# [10, 1, 0, 5, 3, 2, 6]
# -------------------
# [10, 2, 0, 8, 6, 4, 3]
# -------------------
# [10, 7, 0, 2, 6, 8, 3]
# -------------------
# [10, 2, 6, 7, 0, 8, 3]
# -------------------
# [10, 2, 0, 7, 6, 8, 3]
# -------------------
# [10, 1, 0, 2, 3, 5, 6]
# -------------------
# [10, 4, 6, 2, 0, 8, 3]
# -------------------
# [10, 8, 6, 2, 0, 7, 3]
# -------------------
# [10, 4, 0, 2, 6, 8, 3]
# -------------------
# [10, 8, 0, 2, 6, 7, 3]
# -------------------
# [10, 2, 6, 4, 0, 8, 3]
# -------------------
# [10, 2, 0, 5, 3, 1, 6]
# -------------------
# [10, 2, 0, 4, 6, 8, 3]
# -------------------
# [10, 8, 6, 7, 0, 2, 3]
# -------------------
# [10, 8, 0, 7, 6, 2, 3]
# -------------------
# [10, 1, 6, 8, 0, 7, 3]
# -------------------
# [10, 8, 6, 2, 0, 4, 3]
# -------------------
# [10, 7, 6, 1, 0, 8, 3]
# -------------------
# [10, 5, 0, 2, 3, 1, 6]
# -------------------
# [10, 1, 0, 8, 6, 7, 3]
# -------------------
# [10, 8, 0, 2, 6, 4, 3]
# -------------------
# [10, 8, 6, 4, 0, 2, 3]
# -------------------
# [10, 7, 0, 1, 6, 8, 3]
# -------------------
# [10, 8, 0, 4, 6, 2, 3]
# -------------------
# [10, 7, 6, 8, 0, 1, 3]
# -------------------
# [10, 7, 0, 8, 6, 1, 3]
# -------------------
# [10, 8, 6, 1, 0, 7, 3]
# -------------------
# [10, 8, 0, 1, 6, 7, 3]
# -------------------
# [10, 1, 6, 7, 0, 8, 3]
# -------------------
# [10, 1, 0, 7, 6, 8, 3]
# -------------------
# [10, 4, 6, 1, 0, 8, 3]
# -------------------
# [10, 1, 6, 8, 0, 4, 3]
# -------------------
# [10, 4, 0, 1, 6, 8, 3]
# -------------------
# [10, 1, 0, 8, 6, 4, 3]
# -------------------
# [10, 4, 6, 8, 0, 1, 3]
# -------------------
# [10, 4, 0, 8, 6, 1, 3]
# -------------------
# [10, 8, 6, 1, 0, 4, 3]
# -------------------
# [10, 8, 6, 7, 0, 1, 3]
# -------------------
# [10, 1, 6, 4, 0, 8, 3]
# -------------------
# [10, 8, 0, 1, 6, 4, 3]
# -------------------
# [10, 8, 0, 7, 6, 1, 3]
# -------------------
# [10, 1, 0, 4, 6, 8, 3]
# -------------------
# [10, 8, 6, 4, 0, 1, 3]
# -------------------
# [10, 8, 0, 4, 6, 1, 3]
# -------------------
# [10, 2, 3, 1, 0, 5, 6]
# -------------------
# [10, 5, 3, 1, 0, 2, 6]
# -------------------
# [10, 1, 3, 5, 0, 2, 6]
# -------------------
# [10, 1, 3, 2, 0, 5, 6]
# -------------------
# [10, 2, 3, 5, 0, 1, 6]
# -------------------
# [10, 5, 3, 2, 0, 1, 6]
# -------------------
# [10, 0, 1, 5, 2, 3, 8, 6]
# -------------------
# [10, 0, 1, 5, 8, 3, 2, 6]
# -------------------
# [10, 7, 6, 8, 3, 4, 0]
# -------------------
# [10, 4, 6, 8, 3, 7, 0]
# -------------------
# [10, 8, 6, 7, 3, 4, 0]
# -------------------
# [10, 8, 6, 4, 3, 7, 0]
# -------------------
# [10, 0, 1, 3, 2, 5, 8, 6]
# -------------------
# [10, 7, 6, 4, 3, 8, 0]
# -------------------
# [10, 0, 1, 3, 8, 5, 2, 6]
# -------------------
# [10, 7, 3, 8, 6, 4, 0]
# -------------------
# [10, 4, 6, 7, 3, 8, 0]
# -------------------
# [10, 4, 3, 8, 6, 7, 0]
# -------------------
# [10, 5, 6, 1, 0, 2, 3]
# -------------------
# [10, 5, 0, 1, 6, 2, 3]
# -------------------
# [10, 2, 6, 1, 0, 5, 3]
# -------------------
# [10, 8, 3, 7, 6, 4, 0]
# -------------------
# [10, 1, 6, 5, 0, 2, 3]
# -------------------
# [10, 8, 3, 4, 6, 7, 0]
# -------------------
# [10, 2, 0, 1, 6, 5, 3]
# -------------------
# [10, 1, 0, 5, 6, 2, 3]
# -------------------
# [10, 5, 6, 2, 0, 1, 3]
# -------------------
# [10, 2, 6, 5, 0, 1, 3]
# -------------------
# [10, 5, 0, 2, 6, 1, 3]
# -------------------
# [10, 1, 6, 2, 0, 5, 3]
# -------------------
# [10, 7, 3, 4, 6, 8, 0]
# -------------------
# [10, 2, 0, 5, 6, 1, 3]
# -------------------
# [10, 1, 0, 2, 6, 5, 3]
# -------------------
# [10, 4, 3, 7, 6, 8, 0]
# -------------------
# [10, 3, 7, 0, 5, 6]
# -------------------
# [10, 0, 7, 3, 5, 6]
# -------------------
# [10, 3, 5, 0, 7, 6]
# -------------------
# [10, 0, 5, 3, 7, 6]
# -------------------
# [10, 3, 4, 0, 5, 6]
# -------------------
# [10, 0, 4, 3, 5, 6]
# -------------------
# [10, 3, 5, 0, 4, 6]
# -------------------
# [10, 0, 5, 3, 4, 6]
# -------------------
# [10, 1, 0, 8, 3, 5, 6]
# -------------------
# [10, 5, 0, 1, 3, 8, 6]
# -------------------
# [10, 1, 0, 5, 3, 8, 6]
# -------------------
# [10, 8, 0, 1, 3, 5, 6]
# -------------------
# [10, 5, 0, 8, 3, 1, 6]
# -------------------
# [10, 0, 1, 2, 5, 3, 7, 6]
# -------------------
# [10, 8, 0, 5, 3, 1, 6]
# -------------------
# [10, 0, 1, 2, 7, 3, 5, 6]
# -------------------
# [10, 2, 6, 5, 3, 7, 0]
# -------------------
# [10, 0, 7, 6, 5, 3]
# -------------------
# [10, 2, 6, 5, 3, 4, 0]
# -------------------
# [10, 5, 6, 2, 3, 7, 0]
# -------------------
# [10, 5, 6, 2, 3, 4, 0]
# -------------------
# [10, 7, 6, 2, 3, 5, 0]
# -------------------
# [10, 2, 6, 7, 3, 5, 0]
# -------------------
# [10, 0, 5, 6, 7, 3]
# -------------------
# [10, 7, 6, 5, 3, 2, 0]
# -------------------
# [10, 5, 6, 1, 3, 7, 0]
# -------------------
# [10, 2, 6, 4, 3, 5, 0]
# -------------------
# [10, 1, 3, 8, 0, 5, 6]
# -------------------
# [10, 5, 3, 1, 0, 8, 6]
# -------------------
# [10, 1, 6, 5, 3, 7, 0]
# -------------------
# [10, 5, 6, 7, 3, 2, 0]
# -------------------
# [10, 4, 6, 2, 3, 5, 0]
# -------------------
# [10, 7, 6, 1, 3, 5, 0]
# -------------------
# [10, 5, 6, 1, 3, 4, 0]
# -------------------
# [10, 1, 3, 5, 0, 8, 6]
# -------------------
# [10, 5, 6, 4, 3, 2, 0]
# -------------------
# [10, 4, 6, 5, 3, 2, 0]
# -------------------
# [10, 8, 3, 1, 0, 5, 6]
# -------------------
# [10, 1, 6, 5, 3, 4, 0]
# -------------------
# [10, 5, 3, 8, 0, 1, 6]
# -------------------
# [10, 1, 6, 7, 3, 5, 0]
# -------------------
# [10, 7, 6, 5, 3, 1, 0]
# -------------------
# [10, 4, 6, 1, 3, 5, 0]
# -------------------
# [10, 2, 3, 5, 6, 7, 0]
# -------------------
# [10, 2, 3, 5, 6, 4, 0]
# -------------------
# [10, 5, 6, 7, 3, 1, 0]
# -------------------
# [10, 1, 6, 4, 3, 5, 0]
# -------------------
# [10, 5, 3, 2, 6, 7, 0]
# -------------------
# [10, 8, 3, 5, 0, 1, 6]
# -------------------
# [10, 5, 3, 2, 6, 4, 0]
# -------------------
# [10, 7, 3, 2, 6, 5, 0]
# -------------------
# [10, 5, 6, 4, 3, 1, 0]
# -------------------
# [10, 4, 6, 5, 3, 1, 0]
# -------------------
# [10, 2, 3, 7, 6, 5, 0]
# -------------------
# [10, 7, 3, 5, 6, 2, 0]
# -------------------
# [10, 0, 1, 3, 5, 2, 7, 6]
# -------------------
# [10, 5, 3, 1, 6, 7, 0]
# -------------------
# [10, 0, 1, 5, 2, 6, 8, 3]
# -------------------
# [10, 2, 3, 4, 6, 5, 0]
# -------------------
# [10, 5, 3, 7, 6, 2, 0]
# -------------------
# [10, 1, 3, 5, 6, 7, 0]
# -------------------
# [10, 4, 3, 2, 6, 5, 0]
# -------------------
# [10, 7, 3, 1, 6, 5, 0]
# -------------------
# [10, 5, 3, 1, 6, 4, 0]
# -------------------
# [10, 5, 3, 4, 6, 2, 0]
# -------------------
# [10, 4, 3, 5, 6, 2, 0]
# -------------------
# [10, 1, 3, 5, 6, 4, 0]
# -------------------
# [10, 0, 4, 6, 5, 3]
# -------------------
# [10, 1, 3, 7, 6, 5, 0]
# -------------------
# [10, 7, 3, 5, 6, 1, 0]
# -------------------
# [10, 4, 3, 1, 6, 5, 0]
# -------------------
# [10, 0, 1, 5, 8, 6, 2, 3]
# -------------------
# [10, 5, 3, 7, 6, 1, 0]
# -------------------
# [10, 1, 3, 4, 6, 5, 0]
# -------------------
# [10, 0, 5, 6, 4, 3]
# -------------------
# [10, 0, 1, 3, 7, 2, 5, 6]
# -------------------
# [10, 5, 3, 4, 6, 1, 0]
# -------------------
# [10, 4, 3, 5, 6, 1, 0]
# -------------------
# [10, 6, 7, 0, 5, 3]
# -------------------
# [10, 6, 5, 0, 7, 3]
# -------------------
# [10, 0, 1, 2, 5, 3, 4, 6]
# -------------------
# [10, 0, 1, 6, 2, 5, 8, 3]
# -------------------
# [10, 0, 1, 2, 4, 3, 5, 6]
# -------------------
# [10, 6, 4, 0, 5, 3]
# -------------------
# [10, 0, 1, 6, 8, 5, 2, 3]
# -------------------
# [10, 6, 5, 0, 4, 3]
# -------------------
# [10, 0, 1, 3, 5, 2, 4, 6]
# -------------------
# [10, 0, 1, 3, 4, 2, 5, 6]
# -------------------
# [10, 5, 6, 1, 0, 8, 3]
# -------------------
# [10, 5, 0, 1, 6, 8, 3]
# -------------------
# [10, 5, 6, 8, 0, 1, 3]
# -------------------
# [10, 5, 0, 8, 6, 1, 3]
# -------------------
# [10, 1, 6, 8, 0, 5, 3]
# -------------------
# [10, 1, 0, 8, 6, 5, 3]
# -------------------
# [10, 1, 6, 5, 0, 8, 3]
# -------------------
# [10, 1, 0, 5, 6, 8, 3]
# -------------------
# [10, 8, 6, 1, 0, 5, 3]
# -------------------
# [10, 8, 0, 1, 6, 5, 3]
# -------------------
# [10, 8, 6, 5, 0, 1, 3]
# -------------------
# [10, 8, 0, 5, 6, 1, 3]
# -------------------
# [10, 0, 1, 2, 5, 6, 7, 3]
# -------------------
# [10, 0, 1, 6, 5, 2, 7, 3]
# -------------------
# [10, 0, 1, 2, 7, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 7, 2, 5, 3]
# -------------------
# [10, 5, 6, 8, 3, 7, 0]
# -------------------
# [10, 7, 6, 8, 3, 5, 0]
# -------------------
# [10, 5, 6, 8, 3, 4, 0]
# -------------------
# [10, 8, 6, 5, 3, 7, 0]
# -------------------
# [10, 7, 6, 5, 3, 8, 0]
# -------------------
# [10, 4, 6, 8, 3, 5, 0]
# -------------------
# [10, 8, 6, 5, 3, 4, 0]
# -------------------
# [10, 8, 6, 7, 3, 5, 0]
# -------------------
# [10, 5, 6, 7, 3, 8, 0]
# -------------------
# [10, 5, 3, 8, 6, 7, 0]
# -------------------
# [10, 8, 6, 4, 3, 5, 0]
# -------------------
# [10, 5, 6, 4, 3, 8, 0]
# -------------------
# [10, 4, 6, 5, 3, 8, 0]
# -------------------
# [10, 7, 3, 8, 6, 5, 0]
# -------------------
# [10, 0, 1, 2, 5, 6, 4, 3]
# -------------------
# [10, 5, 3, 8, 6, 4, 0]
# -------------------
# [10, 8, 3, 5, 6, 7, 0]
# -------------------
# [10, 7, 3, 5, 6, 8, 0]
# -------------------
# [10, 4, 3, 8, 6, 5, 0]
# -------------------
# [10, 8, 3, 5, 6, 4, 0]
# -------------------
# [10, 8, 3, 7, 6, 5, 0]
# -------------------
# [10, 5, 3, 7, 6, 8, 0]
# -------------------
# [10, 0, 1, 2, 4, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 5, 2, 4, 3]
# -------------------
# [10, 8, 3, 4, 6, 5, 0]
# -------------------
# [10, 5, 3, 4, 6, 8, 0]
# -------------------
# [10, 4, 3, 5, 6, 8, 0]
# -------------------
# [10, 0, 1, 6, 4, 2, 5, 3]
# -------------------
# [10, 0, 1, 3, 5, 8, 7, 6]
# -------------------
# [10, 0, 1, 3, 7, 8, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 8, 4, 6]
# -------------------
# [10, 3, 7, 0, 2, 6]
# -------------------
# [10, 3, 7, 0, 1, 6]
# -------------------
# [10, 0, 7, 3, 2, 6]
# -------------------
# [10, 0, 7, 3, 1, 6]
# -------------------
# [10, 0, 1, 3, 4, 8, 5, 6]
# -------------------
# [10, 3, 1, 0, 7, 6]
# -------------------
# [10, 3, 2, 0, 7, 6]
# -------------------
# [10, 0, 1, 3, 7, 6]
# -------------------
# [10, 0, 2, 3, 7, 6]
# -------------------
# [10, 2, 0, 1, 3, 8, 6]
# -------------------
# [10, 3, 4, 0, 2, 6]
# -------------------
# [10, 1, 0, 8, 3, 2, 6]
# -------------------
# [10, 0, 4, 3, 2, 6]
# -------------------
# [10, 3, 4, 0, 1, 6]
# -------------------
# [10, 8, 0, 1, 3, 2, 6]
# -------------------
# [10, 0, 4, 3, 1, 6]
# -------------------
# [10, 1, 0, 2, 3, 8, 6]
# -------------------
# [10, 2, 0, 8, 3, 1, 6]
# -------------------
# [10, 8, 0, 2, 3, 1, 6]
# -------------------
# [10, 3, 2, 0, 4, 6]
# -------------------
# [10, 3, 1, 0, 4, 6]
# -------------------
# [10, 0, 2, 3, 4, 6]
# -------------------
# [10, 0, 1, 3, 4, 6]
# -------------------
# [10, 2, 3, 1, 0, 8, 6]
# -------------------
# [10, 1, 3, 8, 0, 2, 6]
# -------------------
# [10, 8, 3, 1, 0, 2, 6]
# -------------------
# [10, 1, 3, 2, 0, 8, 6]
# -------------------
# [10, 2, 3, 8, 0, 1, 6]
# -------------------
# [10, 2, 6, 1, 3, 4, 0]
# -------------------
# [10, 8, 3, 2, 0, 1, 6]
# -------------------
# [10, 1, 6, 2, 3, 4, 0]
# -------------------
# [10, 2, 6, 1, 3, 7, 0]
# -------------------
# [10, 4, 6, 1, 3, 2, 0]
# -------------------
# [10, 1, 6, 2, 3, 7, 0]
# -------------------
# [10, 1, 6, 4, 3, 2, 0]
# -------------------
# [10, 2, 6, 4, 3, 1, 0]
# -------------------
# [10, 7, 6, 1, 3, 2, 0]
# -------------------
# [10, 4, 6, 2, 3, 1, 0]
# -------------------
# [10, 2, 3, 1, 6, 4, 0]
# -------------------
# [10, 7, 6, 2, 3, 1, 0]
# -------------------
# [10, 1, 6, 7, 3, 2, 0]
# -------------------
# [10, 2, 6, 7, 3, 1, 0]
# -------------------
# [10, 0, 7, 6, 2, 3]
# -------------------
# [10, 1, 3, 2, 6, 4, 0]
# -------------------
# [10, 2, 3, 1, 6, 7, 0]
# -------------------
# [10, 0, 7, 6, 1, 3]
# -------------------
# [10, 4, 3, 1, 6, 2, 0]
# -------------------
# [10, 1, 3, 2, 6, 7, 0]
# -------------------
# [10, 1, 3, 4, 6, 2, 0]
# -------------------
# [10, 2, 3, 4, 6, 1, 0]
# -------------------
# [10, 7, 3, 1, 6, 2, 0]
# -------------------
# [10, 4, 3, 2, 6, 1, 0]
# -------------------
# [10, 0, 2, 6, 7, 3]
# -------------------
# [10, 0, 1, 6, 5, 8, 7, 3]
# -------------------
# [10, 0, 1, 6, 7, 3]
# -------------------
# [10, 7, 3, 2, 6, 1, 0]
# -------------------
# [10, 1, 3, 7, 6, 2, 0]
# -------------------
# [10, 2, 3, 7, 6, 1, 0]
# -------------------
# [10, 0, 4, 6, 2, 3]
# -------------------
# [10, 0, 1, 6, 7, 8, 5, 3]
# -------------------
# [10, 0, 4, 6, 1, 3]
# -------------------
# [10, 0, 2, 6, 4, 3]
# -------------------
# [10, 0, 1, 6, 4, 3]
# -------------------
# [10, 6, 7, 0, 2, 3]
# -------------------
# [10, 6, 7, 0, 1, 3]
# -------------------
# [10, 6, 2, 0, 7, 3]
# -------------------
# [10, 6, 1, 0, 7, 3]
# -------------------
# [10, 6, 4, 0, 2, 3]
# -------------------
# [10, 6, 4, 0, 1, 3]
# -------------------
# [10, 6, 2, 0, 4, 3]
# -------------------
# [10, 6, 1, 0, 4, 3]
# -------------------
# [10, 0, 1, 6, 5, 8, 4, 3]
# -------------------
# [10, 1, 6, 8, 0, 2, 3]
# -------------------
# [10, 2, 6, 1, 0, 8, 3]
# -------------------
# [10, 1, 0, 8, 6, 2, 3]
# -------------------
# [10, 2, 0, 1, 6, 8, 3]
# -------------------
# [10, 2, 6, 8, 0, 1, 3]
# -------------------
# [10, 2, 0, 8, 6, 1, 3]
# -------------------
# [10, 8, 6, 1, 0, 2, 3]
# -------------------
# [10, 1, 6, 2, 0, 8, 3]
# -------------------
# [10, 8, 0, 1, 6, 2, 3]
# -------------------
# [10, 1, 0, 2, 6, 8, 3]
# -------------------
# [10, 0, 1, 6, 4, 8, 5, 3]
# -------------------
# [10, 8, 6, 2, 0, 1, 3]
# -------------------
# [10, 8, 0, 2, 6, 1, 3]
# -------------------
# [10, 3, 7, 6, 4, 0]
# -------------------
# [10, 3, 4, 6, 7, 0]
# -------------------
# [10, 3, 7, 0, 8, 6]
# -------------------
# [10, 0, 7, 3, 8, 6]
# -------------------
# [10, 6, 7, 3, 4, 0]
# -------------------
# [10, 6, 4, 3, 7, 0]
# -------------------
# [10, 3, 8, 0, 7, 6]
# -------------------
# [10, 0, 8, 3, 7, 6]
# -------------------
# [10, 3, 4, 0, 8, 6]
# -------------------
# [10, 0, 4, 3, 8, 6]
# -------------------
# [10, 0, 1, 2, 8, 3, 7, 6]
# -------------------
# [10, 0, 1, 3, 2, 8, 7, 6]
# -------------------
# [10, 2, 6, 8, 3, 4, 0]
# -------------------
# [10, 2, 6, 8, 3, 7, 0]
# -------------------
# [10, 8, 6, 2, 3, 4, 0]
# -------------------
# [10, 4, 6, 8, 3, 2, 0]
# -------------------
# [10, 3, 8, 0, 4, 6]
# -------------------
# [10, 0, 8, 3, 4, 6]
# -------------------
# [10, 7, 6, 8, 3, 2, 0]
# -------------------
# [10, 2, 6, 4, 3, 8, 0]
# -------------------
# [10, 8, 6, 2, 3, 7, 0]
# -------------------
# [10, 1, 6, 8, 3, 4, 0]
# -------------------
# [10, 4, 6, 2, 3, 8, 0]
# -------------------
# [10, 2, 3, 8, 6, 4, 0]
# -------------------
# [10, 8, 6, 4, 3, 2, 0]
# -------------------
# [10, 0, 1, 2, 7, 3, 8, 6]
# -------------------
# [10, 1, 6, 8, 3, 7, 0]
# -------------------
# [10, 7, 6, 2, 3, 8, 0]
# -------------------
# [10, 8, 6, 1, 3, 4, 0]
# -------------------
# [10, 2, 6, 7, 3, 8, 0]
# -------------------
# [10, 0, 1, 3, 7, 8, 2, 6]
# -------------------
# [10, 8, 6, 7, 3, 2, 0]
# -------------------
# [10, 8, 6, 1, 3, 7, 0]
# -------------------
# [10, 2, 3, 8, 6, 7, 0]
# -------------------
# [10, 7, 6, 8, 3, 1, 0]
# -------------------
# [10, 4, 6, 8, 3, 1, 0]
# -------------------
# [10, 8, 3, 2, 6, 4, 0]
# -------------------
# [10, 7, 6, 1, 3, 8, 0]
# -------------------
# [10, 4, 6, 1, 3, 8, 0]
# -------------------
# [10, 4, 3, 8, 6, 2, 0]
# -------------------
# [10, 1, 6, 4, 3, 8, 0]
# -------------------
# [10, 7, 3, 8, 6, 2, 0]
# -------------------
# [10, 2, 3, 4, 6, 8, 0]
# -------------------
# [10, 8, 3, 2, 6, 7, 0]
# -------------------
# [10, 1, 6, 7, 3, 8, 0]
# -------------------
# [10, 1, 3, 8, 6, 4, 0]
# -------------------
# [10, 8, 6, 4, 3, 1, 0]
# -------------------
# [10, 4, 3, 2, 6, 8, 0]
# -------------------
# [10, 8, 3, 4, 6, 2, 0]
# -------------------
# [10, 8, 6, 7, 3, 1, 0]
# -------------------
# [10, 7, 3, 2, 6, 8, 0]
# -------------------
# [10, 1, 3, 8, 6, 7, 0]
# -------------------
# [10, 2, 3, 7, 6, 8, 0]
# -------------------
# [10, 8, 3, 1, 6, 4, 0]
# -------------------
# [10, 0, 1, 3, 8, 2, 7, 6]
# -------------------
# [10, 8, 3, 7, 6, 2, 0]
# -------------------
# [10, 8, 3, 1, 6, 7, 0]
# -------------------
# [10, 7, 3, 8, 6, 1, 0]
# -------------------
# [10, 4, 3, 8, 6, 1, 0]
# -------------------
# [10, 7, 3, 1, 6, 8, 0]
# -------------------
# [10, 4, 3, 1, 6, 8, 0]
# -------------------
# [10, 1, 3, 4, 6, 8, 0]
# -------------------
# [10, 1, 3, 7, 6, 8, 0]
# -------------------
# [10, 8, 3, 4, 6, 1, 0]
# -------------------
# [10, 8, 3, 7, 6, 1, 0]
# -------------------
# [10, 0, 1, 2, 8, 3, 4, 6]
# -------------------
# [10, 0, 7, 6, 8, 3]
# -------------------
# [10, 0, 1, 3, 7, 2, 8, 6]
# -------------------
# [10, 0, 1, 3, 2, 8, 4, 6]
# -------------------
# [10, 0, 8, 6, 7, 3]
# -------------------
# [10, 0, 1, 2, 4, 3, 8, 6]
# -------------------
# [10, 0, 4, 6, 8, 3]
# -------------------
# [10, 0, 1, 3, 4, 8, 2, 6]
# -------------------
# [10, 0, 8, 6, 4, 3]
# -------------------
# [10, 6, 7, 0, 8, 3]
# -------------------
# [10, 0, 1, 3, 8, 2, 4, 6]
# -------------------
# [10, 6, 8, 0, 7, 3]
# -------------------
# [10, 0, 1, 3, 4, 2, 8, 6]
# -------------------
# [10, 6, 4, 0, 8, 3]
# -------------------
# [10, 6, 8, 0, 4, 3]
# -------------------
# [10, 3, 5, 0, 2, 6]
# -------------------
# [10, 3, 5, 0, 1, 6]
# -------------------
# [10, 0, 5, 3, 2, 6]
# -------------------
# [10, 0, 5, 3, 1, 6]
# -------------------
# [10, 3, 1, 0, 5, 6]
# -------------------
# [10, 3, 2, 0, 5, 6]
# -------------------
# [10, 0, 1, 3, 5, 6]
# -------------------
# [10, 0, 2, 3, 5, 6]
# -------------------
# [10, 2, 6, 1, 3, 5, 0]
# -------------------
# [10, 5, 6, 1, 3, 2, 0]
# -------------------
# [10, 1, 6, 2, 3, 5, 0]
# -------------------
# [10, 1, 6, 5, 3, 2, 0]
# -------------------
# [10, 2, 6, 5, 3, 1, 0]
# -------------------
# [10, 5, 6, 2, 3, 1, 0]
# -------------------
# [10, 2, 3, 1, 6, 5, 0]
# -------------------
# [10, 5, 3, 1, 6, 2, 0]
# -------------------
# [10, 1, 3, 2, 6, 5, 0]
# -------------------
# [10, 1, 3, 5, 6, 2, 0]
# -------------------
# [10, 2, 3, 5, 6, 1, 0]
# -------------------
# [10, 5, 3, 2, 6, 1, 0]
# -------------------
# [10, 0, 1, 6, 2, 8, 7, 3]
# -------------------
# [10, 0, 5, 6, 2, 3]
# -------------------
# [10, 0, 2, 6, 5, 3]
# -------------------
# [10, 0, 5, 6, 1, 3]
# -------------------
# [10, 0, 1, 6, 7, 8, 2, 3]
# -------------------
# [10, 0, 1, 6, 5, 3]
# -------------------
# [10, 0, 1, 2, 8, 6, 7, 3]
# -------------------
# [10, 0, 1, 2, 7, 6, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 2, 7, 3]
# -------------------
# [10, 0, 1, 6, 7, 2, 8, 3]
# -------------------
# [10, 6, 5, 0, 2, 3]
# -------------------
# [10, 6, 2, 0, 5, 3]
# -------------------
# [10, 6, 5, 0, 1, 3]
# -------------------
# [10, 6, 1, 0, 5, 3]
# -------------------
# [10, 0, 1, 6, 2, 8, 4, 3]
# -------------------
# [10, 0, 1, 6, 4, 8, 2, 3]
# -------------------
# [10, 0, 1, 2, 4, 6, 8, 3]
# -------------------
# [10, 0, 1, 2, 8, 6, 4, 3]
# -------------------
# [10, 0, 1, 6, 4, 2, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 2, 4, 3]
# -------------------
# [10, 3, 7, 6, 5, 0]
# -------------------
# [10, 3, 5, 6, 7, 0]
# -------------------
# [10, 6, 7, 3, 5, 0]
# -------------------
# [10, 3, 4, 6, 5, 0]
# -------------------
# [10, 6, 5, 3, 7, 0]
# -------------------
# [10, 3, 5, 6, 4, 0]
# -------------------
# [10, 6, 4, 3, 5, 0]
# -------------------
# [10, 6, 5, 3, 4, 0]
# -------------------
# [10, 0, 1, 2, 8, 3, 5, 6]
# -------------------
# [10, 0, 1, 2, 5, 3, 8, 6]
# -------------------
# [10, 0, 1, 3, 2, 8, 5, 6]
# -------------------
# [10, 3, 5, 0, 8, 6]
# -------------------
# [10, 0, 5, 3, 8, 6]
# -------------------
# [10, 1, 6, 8, 3, 5, 0]
# -------------------
# [10, 0, 1, 3, 5, 8, 2, 6]
# -------------------
# [10, 5, 6, 8, 3, 1, 0]
# -------------------
# [10, 8, 6, 1, 3, 5, 0]
# -------------------
# [10, 5, 6, 1, 3, 8, 0]
# -------------------
# [10, 3, 8, 0, 5, 6]
# -------------------
# [10, 0, 8, 3, 5, 6]
# -------------------
# [10, 1, 6, 5, 3, 8, 0]
# -------------------
# [10, 8, 6, 5, 3, 1, 0]
# -------------------
# [10, 1, 3, 8, 6, 5, 0]
# -------------------
# [10, 5, 3, 8, 6, 1, 0]
# -------------------
# [10, 8, 3, 1, 6, 5, 0]
# -------------------
# [10, 5, 3, 1, 6, 8, 0]
# -------------------
# [10, 0, 1, 3, 8, 2, 5, 6]
# -------------------
# [10, 1, 3, 5, 6, 8, 0]
# -------------------
# [10, 8, 3, 5, 6, 1, 0]
# -------------------
# [10, 0, 1, 3, 5, 2, 8, 6]
# -------------------
# [10, 0, 5, 6, 8, 3]
# -------------------
# [10, 0, 8, 6, 5, 3]
# -------------------
# [10, 6, 5, 0, 8, 3]
# -------------------
# [10, 6, 8, 0, 5, 3]
# -------------------
# [10, 0, 1, 6, 5, 8, 2, 3]
# -------------------
# [10, 0, 1, 2, 5, 6, 8, 3]
# -------------------
# [10, 0, 1, 6, 2, 8, 5, 3]
# -------------------
# [10, 0, 1, 2, 8, 6, 5, 3]
# -------------------
# [10, 0, 1, 6, 5, 2, 8, 3]
# -------------------
# [10, 0, 1, 6, 8, 2, 5, 3]
# -------------------
# [10, 3, 1, 0, 2, 6]
# -------------------
# [10, 0, 1, 3, 2, 6]
# -------------------
# [10, 3, 2, 0, 1, 6]
# -------------------
# [10, 0, 2, 3, 1, 6]
# -------------------
# [10, 0, 1, 6, 2, 3]
# -------------------
# [10, 0, 2, 6, 1, 3]
# -------------------
# [10, 6, 1, 0, 2, 3]
# -------------------
# [10, 6, 2, 0, 1, 3]
# -------------------
# [10, 3, 7, 6, 1, 0]
# -------------------
# [10, 3, 7, 6, 2, 0]
# -------------------
# [10, 3, 1, 6, 7, 0]
# -------------------
# [10, 6, 7, 3, 2, 0]
# -------------------
# [10, 6, 7, 3, 1, 0]
# -------------------
# [10, 3, 2, 6, 7, 0]
# -------------------
# [10, 3, 4, 6, 2, 0]
# -------------------
# [10, 3, 4, 6, 1, 0]
# -------------------
# [10, 6, 1, 3, 7, 0]
# -------------------
# [10, 3, 1, 6, 4, 0]
# -------------------
# [10, 6, 2, 3, 7, 0]
# -------------------
# [10, 6, 4, 3, 2, 0]
# -------------------
# [10, 3, 2, 6, 4, 0]
# -------------------
# [10, 6, 4, 3, 1, 0]
# -------------------
# [10, 1, 6, 8, 3, 2, 0]
# -------------------
# [10, 2, 6, 8, 3, 1, 0]
# -------------------
# [10, 2, 6, 1, 3, 8, 0]
# -------------------
# [10, 6, 1, 3, 4, 0]
# -------------------
# [10, 8, 6, 1, 3, 2, 0]
# -------------------
# [10, 6, 2, 3, 4, 0]
# -------------------
# [10, 1, 6, 2, 3, 8, 0]
# -------------------
# [10, 8, 6, 2, 3, 1, 0]
# -------------------
# [10, 1, 3, 8, 6, 2, 0]
# -------------------
# [10, 2, 3, 8, 6, 1, 0]
# -------------------
# [10, 2, 3, 1, 6, 8, 0]
# -------------------
# [10, 3, 2, 0, 8, 6]
# -------------------
# [10, 0, 2, 3, 8, 6]
# -------------------
# [10, 3, 1, 0, 8, 6]
# -------------------
# [10, 8, 3, 1, 6, 2, 0]
# -------------------
# [10, 3, 8, 0, 2, 6]
# -------------------
# [10, 0, 1, 3, 8, 6]
# -------------------
# [10, 0, 8, 3, 2, 6]
# -------------------
# [10, 1, 3, 2, 6, 8, 0]
# -------------------
# [10, 3, 8, 0, 1, 6]
# -------------------
# [10, 8, 3, 2, 6, 1, 0]
# -------------------
# [10, 0, 8, 3, 1, 6]
# -------------------
# [10, 0, 2, 6, 8, 3]
# -------------------
# [10, 0, 8, 6, 2, 3]
# -------------------
# [10, 0, 1, 6, 8, 3]
# -------------------
# [10, 0, 8, 6, 1, 3]
# -------------------
# [10, 6, 2, 0, 8, 3]
# -------------------
# [10, 6, 8, 0, 2, 3]
# -------------------
# [10, 6, 1, 0, 8, 3]
# -------------------
# [10, 6, 8, 0, 1, 3]
# -------------------
# [10, 3, 7, 6, 8, 0]
# -------------------
# [10, 6, 7, 3, 8, 0]
# -------------------
# [10, 3, 8, 6, 7, 0]
# -------------------
# [10, 3, 4, 6, 8, 0]
# -------------------
# [10, 6, 8, 3, 7, 0]
# -------------------
# [10, 6, 4, 3, 8, 0]
# -------------------
# [10, 3, 8, 6, 4, 0]
# -------------------
# [10, 6, 8, 3, 4, 0]
# -------------------
# [10, 3, 1, 6, 5, 0]
# -------------------
# [10, 3, 5, 6, 1, 0]
# -------------------
# [10, 3, 5, 6, 2, 0]
# -------------------
# [10, 3, 2, 6, 5, 0]
# -------------------
# [10, 6, 1, 3, 5, 0]
# -------------------
# [10, 6, 5, 3, 1, 0]
# -------------------
# [10, 6, 5, 3, 2, 0]
# -------------------
# [10, 6, 2, 3, 5, 0]
# -------------------
# [10, 3, 5, 6, 8, 0]
# -------------------
# [10, 3, 8, 6, 5, 0]
# -------------------
# [10, 6, 5, 3, 8, 0]
# -------------------
# [10, 6, 8, 3, 5, 0]
# -------------------
# [10, 3, 1, 6, 2, 0]
# -------------------
# [10, 3, 2, 6, 1, 0]
# -------------------
# [10, 6, 1, 3, 2, 0]
# -------------------
# [10, 6, 2, 3, 1, 0]
# -------------------
# [10, 3, 1, 6, 8, 0]
# -------------------
# [10, 3, 2, 6, 8, 0]
# -------------------
# [10, 3, 8, 6, 2, 0]
# -------------------
# [10, 3, 8, 6, 1, 0]
# -------------------
# [10, 6, 1, 3, 8, 0]
# -------------------
# [10, 6, 2, 3, 8, 0]
# -------------------
# [10, 6, 8, 3, 2, 0]
# -------------------
# [10, 6, 8, 3, 1, 0]
# -------------------

# %%
from alphatoe import game

for moves in first_component_games:
    game.play_game(moves)
    print("-------------------")
# Out:
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | O | O |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | O | O |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | O | O |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | O | O |
# | X | X |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | O |   |
# | X | X |   |
# -------------------
# | X | O | O |
# | X | O |   |
# | X | X |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | O |   |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | O |   |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X | X | O |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   | O |
# | X | X |   |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   | O |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X | X | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | X | O |   |
# | X | X |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | X | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   | O |
# | X | X |   |
# -------------------
# | X | O | O |
# | X |   | O |
# | X | X |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X | X | O |
# -------------------
# | X | O |   |
# | X | O |   |
# | X | X | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | X | O |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | X | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | X | O |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | X | O |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | X | O |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | X | O |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | X | O |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X | X |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | X | O |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | X | O |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | X | O | O |
# | X |   | X |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X | O | X |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O | X |   |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | X | O |   |
# | X |   | X |
# | X | O | O |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | X | O |   |
# | X | O | X |
# | X |   | O |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O | X |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O |   |   |
# | O | X |   |
# | O | X | X |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O |   | X |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | O | X |   |
# | O |   | X |
# | O | X |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | O | X |   |
# | O | X | X |
# | O |   |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   | X |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | X | O | X |
# | X |   | O |
# | X | O |   |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | O |   |   |
# | O |   | X |
# | O | X | X |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | O |   |   |
# | O | X | X |
# | O |   | X |
# -------------------
# | X | O | X |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | O | X |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | O | X |
# -------------------
# | X | O |   |
# | X | O | O |
# | X |   | X |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | O | O |
# | X |   | X |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O | X |   |
# | O |   |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | O | X |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O | X |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X | O | X |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O | O |
# | X |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X | O |   |
# | X | O | O |
# | X |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O |   |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | O | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | O | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O |   | X |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | O |   | X |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | O | X |   |
# | O | X |   |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   |   |
# | O | X | X |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | O |
# | X | O |   |
# | X |   | X |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X | O | O |
# | X | O |   |
# | X |   | X |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | O | X | X |
# | O |   | X |
# | O |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | O | X |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X | O | X |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | X | O | X |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O | O |
# | X | O |   |
# | X |   | X |
# -------------------
# | X | O | O |
# | X | O |   |
# | X |   | X |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X | O | X |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X | O |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X | O | O |
# | X |   |   |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   | O |
# | X |   | X |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X | O | O |
# | X |   | O |
# | X |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | O | X |   |
# | O |   | X |
# | O |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   | O |
# | X |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   | O |
# | X |   | X |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | X |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X | O |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   |   |
# | X | O |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X | O |   |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   | O |
# | X | O |   |
# | X |   |   |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | O | X | X |
# | O |   |   |
# | O |   | X |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   |   |
# | X | O | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X |   |   |
# | X | O |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   | O |
# | X |   | O |
# | X |   |   |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X |   |   |
# | X |   | O |
# | X |   | O |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O | O |
# | X |   |   |
# | X |   |   |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X |   | O |
# | X |   |   |
# | X |   | O |
# -------------------
# | X | O |   |
# | X |   |   |
# | X |   | O |
# -------------------

# %% [markdown]
# ### That didn't really work. The principal vectors aren't really interpretable..

# %% [markdown]
# ### Maybe we can just get some information about the variance across all games

# %%
games = pd.read_csv("../data/prob all 8 layer control-20230718-185339_stats.csv")
# Out:
# /tmp/ipykernel_4489/1262955292.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   games = pd.read_csv("../data/prob all 8 layer control-20230718-185339_stats.csv")

# %%
all_games = [eval(moves) for moves in games["moves played"]]

# %%
all_logits = interpretability.inference_on_games(model, all_games)

# %%
for logits in all_logits:
    print(len(logits))
# Out:
# 1440
# 5328
# 47952
# 72576
# 127871

# %%
with torch.no_grad():
    all_residuals = [
        pre_mlp_residual(torch.tensor(game)) for game in tqdm.tqdm(all_games)
    ]
# Out:
#   4%|▍         | 9802/255168 [00:04<01:50, 2210.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 with torch.no_grad():
# ----> 2     all_residuals = [
#       3         pre_mlp_residual(torch.tensor(game)) for game in tqdm.tqdm(all_games)
#       4     ]
#
# Cell In[27], line 3, in <listcomp>(.0)
#       1 with torch.no_grad():
#       2     all_residuals = [
# ----> 3         pre_mlp_residual(torch.tensor(game)) for game in tqdm.tqdm(all_games)
#       4     ]
#
# Cell In[6], line 9, in pre_mlp_residual(seq)
#       7 handle = model.blocks[0].hook_resid_mid.register_forward_hook(hook)
#       8 with torch.no_grad():
# ----> 9     model(seq)
#      10 activations = model.blocks[0].hook_resid_mid.captured
#      11 handle.remove()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformer_lens/HookedTransformer.py:337, in HookedTransformer.forward(self, input, return_type, loss_per_token, prepend_bos, stop_at_layer, past_kv_cache)
#     332     if shortformer_pos_embed is not None:
#     333         shortformer_pos_embed = shortformer_pos_embed.to(
#     334             devices.get_device_for_block_index(i, self.cfg)
#     335         )
# --> 337     residual = block(
#     338         residual,
#     339         past_kv_cache_entry=past_kv_cache[i]
#     340         if past_kv_cache is not None
#     341         else None,  # Cache contains a list of HookedTransformerKeyValueCache objects, one for each block
#     342         shortformer_pos_embed=shortformer_pos_embed,
#     343     )  # [batch, pos, d_model]
#     345 if stop_at_layer is not None:
#     346     # When we stop at an early layer, we end here rather than doing further computation
#     347     return None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformer_lens/components.py:836, in TransformerBlock.forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry)
#     831     resid_mid = self.hook_resid_mid(
#     832         resid_pre + attn_out
#     833     )  # [batch, pos, d_model]
#     834     normalized_resid_mid = self.ln2(resid_mid)
#     835     mlp_out = self.hook_mlp_out(
# --> 836         self.mlp(normalized_resid_mid)
#     837     )  # [batch, pos, d_model]
#     838     resid_post = self.hook_resid_post(
#     839         resid_mid + mlp_out
#     840     )  # [batch, pos, d_model]
#     841 elif self.cfg.parallel_attn_mlp:
#     842     # Dumb thing done by GPT-J, both MLP and Attn read from resid_pre and write to resid_post, no resid_mid used.
#     843     # In GPT-J, LN1 and LN2 are tied, in GPT-NeoX they aren't.
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformer_lens/components.py:631, in MLP.forward(self, x)
#     627 def forward(
#     628     self, x: Float[torch.Tensor, "batch pos d_model"]
#     629 ) -> Float[torch.Tensor, "batch pos d_model"]:
#     630     # Technically, all these einsums could be done with a single matmul, but this is more readable.
# --> 631     pre_act = self.hook_pre(
#     632         einsum("batch pos d_model, d_model d_mlp -> batch pos d_mlp", x, self.W_in)
#     633         + self.b_in
#     634     )  # [batch, pos, d_mlp]
#     635     if not self.cfg.act_fn.endswith("_ln"):
#     636         post_act = self.hook_post(self.act_fn(pre_act))  # [batch, pos, d_mlp]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1188, in Module._call_impl(self, *input, **kwargs)
#    1185             tracing_state.pop_scope()
#    1186     return result
# -> 1188 def _call_impl(self, *input, **kwargs):
#    1189     forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1190     # If we don't have any hooks, we want to skip the rest of the logic in
#    1191     # this function, and just call forward.
#
# KeyboardInterrupt:
