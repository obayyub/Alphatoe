# %%
import torch
import transformer_lens
from src.game import Board, get_best_moves, apply_best_moves, generate_all_games, State
from src.game import Board, minimax
import numpy as np

# %%
board = Board()

# %%
board = Board()
im_dumb = generate_all_games([board])

# %%
len(im_dumb)
# Out:
# 255168

# %%
board.make_move(0)
board.draw_board()
# Out:
# | X |   |   |
# |   |   |   |
# |   |   |   |

# %%
minimax(board)
# Out:
# 0

# %%
board.make_move(2)
board.draw_board()
# Out:
# | X |   | O |
# |   |   |   |
# |   |   |   |

# %%
boards = [Board()]
game_list = apply_best_moves(boards)

# %%
print(len(game_list))
print(game_list[-1].moves_played)
print(len({tuple(game.moves_played) for game in game_list}))
print(len(list(filter(lambda game: game.game_state == State.DRAW, game_list))))
a = all((board.game_state == State.DRAW) for board in game_list)
# Out:
# 3584
# [8, 4, 7, 6, 2, 5, 3, 1, 0]
# 3584
# 3584

# %%
def seq_is_matched(input: list[int], seq: list[int]) -> bool:
    return all(seq[i] == input[i] for i in range(len(seq)))

# %%
for i in range(9):
    print(i, ': ', len([game.moves_played for game in game_list if seq_is_matched(game.moves_played, [i])]))
# Out:
# 0 :  82
# 1 :  758
# 2 :  82
# 3 :  758
# 4 :  224
# 5 :  758
# 6 :  82
# 7 :  758
# 8 :  82

# %%
board = Board()
get_best_moves(board)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
#new np array
moves = np.array([[10] + game.moves_played + [9] for game in game_list])
print(moves.shape)

#np save
np.save("data/moves.npy", moves)
# Out:
# (46080, 11)

# %%
print(moves[1])
# Out:
# [10  0  1  2  3  4  6  7  8  5  9]

# %%
for game in game_list:
    print(game.moves_played)
# Out:
# [0, 1, 2, 3, 4, 6, 5, 8, 7]
# [0, 1, 2, 3, 4, 6, 7, 8, 5]
# [0, 1, 2, 3, 4, 8, 5, 6, 7]
# [0, 1, 2, 3, 4, 8, 7, 6, 5]
# [0, 1, 2, 3, 5, 4, 6, 8, 7]
# [0, 1, 2, 3, 5, 4, 7, 8, 6]
# [0, 1, 2, 3, 5, 6, 4, 8, 7]
# [0, 1, 2, 3, 5, 6, 7, 8, 4]
# [0, 1, 2, 3, 5, 8, 4, 6, 7]
# [0, 1, 2, 3, 5, 8, 6, 4, 7]
# [0, 1, 2, 3, 5, 8, 7, 4, 6]
# [0, 1, 2, 3, 5, 8, 7, 6, 4]
# [0, 1, 2, 3, 6, 4, 5, 8, 7]
# [0, 1, 2, 3, 6, 4, 7, 8, 5]
# [0, 1, 2, 3, 6, 8, 5, 4, 7]
# [0, 1, 2, 3, 6, 8, 7, 4, 5]
# [0, 1, 2, 3, 7, 4, 5, 8, 6]
# [0, 1, 2, 3, 7, 4, 6, 8, 5]
# [0, 1, 2, 3, 7, 6, 4, 8, 5]
# [0, 1, 2, 3, 7, 6, 5, 8, 4]
# [0, 1, 2, 3, 7, 8, 4, 6, 5]
# [0, 1, 2, 3, 7, 8, 5, 4, 6]
# [0, 1, 2, 3, 7, 8, 5, 6, 4]
# [0, 1, 2, 3, 7, 8, 6, 4, 5]
# [0, 1, 2, 4, 3, 5, 7, 6, 8]
# [0, 1, 2, 4, 3, 5, 8, 6, 7]
# [0, 1, 2, 4, 3, 6, 5, 8, 7]
# [0, 1, 2, 4, 3, 6, 7, 5, 8]
# [0, 1, 2, 4, 3, 6, 7, 8, 5]
# [0, 1, 2, 4, 3, 6, 8, 5, 7]
# [0, 1, 2, 4, 3, 8, 5, 6, 7]
# [0, 1, 2, 4, 3, 8, 7, 6, 5]
# [0, 1, 2, 4, 5, 3, 6, 8, 7]
# ...

# %%
boards = [Board()]
boards = [board.make_move(move).moves_played for board in boards for move in get_best_moves(board)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 boards = [Board()]
# ----> 2 boards = [board.make_move(move).moves_played for board in boards for move in get_best_moves(board)]
#
# Cell In[7], line 2, in <listcomp>(.0)
#       1 boards = [Board()]
# ----> 2 boards = [board.make_move(move).moves_played for board in boards for move in get_best_moves(board)]
#
# AttributeError: 'NoneType' object has no attribute 'moves_played'

# %%
print(boards)
# Out:
# [[0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8], [0, 1, 2, 3, 4, 5, 6, 7, 8]]
